# %%
import pandas as pd

# %% [markdown]
# ## Connect to PG Database

# %%
import psycopg2
import os
from dotenv import load_dotenv

load_dotenv("../postgres/.env")
# Out:
# True

# %%
PG_USER = os.getenv('POSTGRES_USER')
PG_PW = os.getenv('POSTGRES_PASSWORD')
PG_DB = os.getenv('POSTGRES_DB')

# %%
postgres_conn_args = {
    "host": "localhost",
    "database": PG_DB,
    "user": PG_USER,
    "password": PG_PW,
    "port": 5432
}

# %%
pg_conn = psycopg2.connect(**postgres_conn_args)

# %%
table_reference = "blogs_dev_staging.stg_reddit__zero_shot"
n = 3
exclude_columns = "id,post_utc_date_created_at,zero_shot_text"
text_column = "zero_shot_text"
date_column = "post_utc_date_created_at"
top_n_table = "blogs_dev_staging.stg_reddit__transpose_zero_shot"
is_incremental = False
incremental_interval = '3 day'

# %%
import pandas as pd

top_n_columns = [f"zero_shot_feature_{idx}" for idx in range(n)]
exclude_columns_list = exclude_columns.split(",")

incremental_query = (
    f"""
WHERE {date_column} >= (
SELECT
    max({date_column}) - interval '{incremental_interval}'
FROM {top_n_table}
)
"""
    if is_incremental
    else ""
)

Q = f"""
SELECT *
FROM
    {table_reference}
{incremental_query}
"""

# %%
print(Q)
# Out:
# SELECT *
# FROM
#     blogs_dev_staging.stg_reddit__zero_shot

# %%
exclude_columns_list
# Out:
# ['id', 'post_utc_date_created_at', 'zero_shot_text']

# %%
with pg_conn:
    df = pd.read_sql(Q, pg_conn)

# %%
if df.empty:
    exclude_columns_list.remove(text_column)
    df_results = pd.DataFrame(columns=(exclude_columns_list + top_n_columns))

else:
    df_filtered = df[df.columns.drop(exclude_columns_list)]
    df_filtered = df_filtered.apply(pd.to_numeric)
    df_t=pd.DataFrame(df_filtered).T

    df_top_n = pd.DataFrame(columns=top_n_columns)
    for i in df_t.columns:
        df_row = pd.DataFrame(df_t.nlargest(n, i).index.tolist(), index=top_n_columns).T
        df_top_n = pd.concat([df_top_n, df_row], axis=0)
    df_top_n.reset_index(drop=True, inplace=True)

    df_results = df.join(df_top_n)
    exclude_columns_list.remove(text_column)
    df_results = df_results[(exclude_columns_list + top_n_columns)]

# %%
df_t
# Out:
#                                0         1         2         3         4   \
# career                   0.534455  0.141005  0.610036  0.695442  0.564078
# ci_cd                    0.100304  0.054991  0.317547  0.004628  0.000427
# container_orchestration  0.179832  0.046972  0.132781  0.002924  0.035447
# data_ingestion           0.257356  0.497458  0.428740  0.167560  0.030053
# data_lake                0.131036  0.089872  0.297882  0.014979  0.018639
# data_lakehouse           0.285507  0.144968  0.173472  0.021803  0.202316
# data_mesh                0.515945  0.177162  0.254806  0.092731  0.030059
# data_orchestration       0.544580  0.788386  0.519185  0.347691  0.089702
# data_transform           0.237736  0.647944  0.496813  0.077574  0.056414
# data_warehouse           0.219351  0.700686  0.445353  0.015754  0.016460
# etl_jobs                 0.069878  0.048917  0.219436  0.017437  0.027749
# learning                 0.328071  0.979040  0.808945  0.938391  0.911352
# scheduling               0.040957  0.158083  0.584255  0.089701  0.103728
# streaming                0.066578  0.155553  0.510787  0.077023  0.388229
#
#                                5         6         7         8         9   \
# career                   0.144809  0.509253  0.734711  0.329324  0.876295
# ci_cd                    0.066024  0.006089  0.066514  0.100293  0.193207
# container_orchestration  0.786490  0.010628  0.053848  0.064657  0.045508
# data_ingestion           0.070273  0.068305  0.310522  0.470500  0.387505
# data_lake                0.059652  0.095155  0.234905  0.305511  0.131129
# data_lakehouse           0.253639  0.238004  0.205466  0.292468  0.229841
# data_mesh                0.154191  0.180866  0.235982  0.277067  0.222526
# data_orchestration       0.625179  0.062305  0.251255  0.412039  0.290090
# data_transform           0.124693  0.143855  0.299283  0.310724  0.372212
# data_warehouse           0.098559  0.054419  0.197366  0.266008  0.268899
# etl_jobs                 0.048577  0.034067  0.076045  0.130638  0.185267
# learning                 0.399778  0.901122  0.799596  0.868781  0.985058
# scheduling               0.197562  0.047473  0.256644  0.226601  0.194271
# streaming                0.741686  0.168244  0.294716  0.307237  0.678592
#
#                          ...        16        17        18        19  \
# career                   ...  0.312362  0.326311  0.072127  0.924495
# ci_cd                    ...  0.436179  0.139757  0.025910  0.027221
# container_orchestration  ...  0.052265  0.223687  0.055157  0.005659
# data_ingestion           ...  0.339755  0.590160  0.144416  0.426798
# data_lake                ...  0.107749  0.285738  0.075298  0.119592
# data_lakehouse           ...  0.036662  0.238195  0.000643  0.019204
# data_mesh                ...  0.125807  0.315908  0.110129  0.352854
# data_orchestration       ...  0.727814  0.591882  0.437134  0.516862
# data_transform           ...  0.211523  0.435180  0.139495  0.154322
# data_warehouse           ...  0.177575  0.490567  0.262649  0.161543
# etl_jobs                 ...  0.160671  0.253085  0.063167  0.131277
# learning                 ...  0.509085  0.624989  0.709675  0.847116
# scheduling               ...  0.366641  0.469784  0.119675  0.466948
# streaming                ...  0.130626  0.296500  0.161349  0.096370
#
#                                20        21        22        23        24  \
# career                   0.116482  0.769924  0.101979  0.103798  0.962993
# ci_cd                    0.127119  0.584580  0.038263  0.023130  0.248705
# container_orchestration  0.026263  0.048808  0.097063  0.048047  0.080922
# data_ingestion           0.556502  0.613156  0.355754  0.376484  0.207497
# data_lake                0.992924  0.208874  0.392662  0.146339  0.235999
# data_lakehouse           0.095303  0.384115  0.403455  0.375640  0.315218
# data_mesh                0.249413  0.192265  0.483176  0.226111  0.311319
# data_orchestration       0.915069  0.249599  0.419670  0.347103  0.235030
# data_transform           0.215883  0.306279  0.420478  0.298390  0.320939
# data_warehouse           0.706747  0.228156  0.193360  0.116606  0.201492
# etl_jobs                 0.033931  0.286485  0.183737  0.062952  0.112973
# learning                 0.830419  0.948125  0.992942  0.998190  0.935020
# scheduling               0.223910  0.061397  0.344434  0.179613  0.247678
# streaming                0.141736  0.289237  0.460542  0.245240  0.340567
#
#                                25
# career                   0.878054
# ci_cd                    0.182176
# container_orchestration  0.045917
# data_ingestion           0.125505
# data_lake                0.162288
# data_lakehouse           0.145944
# data_mesh                0.148986
# data_orchestration       0.100657
# data_transform           0.191071
# data_warehouse           0.106329
# etl_jobs                 0.078658
# learning                 0.301566
# scheduling               0.086557
# streaming                0.295934
#
# [14 rows x 26 columns]

# %%
df_filtered
# Out:
#       career     ci_cd  container_orchestration  data_ingestion  data_lake  \
# 0   0.534455  0.100304                 0.179832        0.257356   0.131036
# 1   0.141005  0.054991                 0.046972        0.497458   0.089872
# 2   0.610036  0.317547                 0.132781        0.428740   0.297882
# 3   0.695442  0.004628                 0.002924        0.167560   0.014979
# 4   0.564078  0.000427                 0.035447        0.030053   0.018639
# 5   0.144809  0.066024                 0.786490        0.070273   0.059652
# 6   0.509253  0.006089                 0.010628        0.068305   0.095155
# 7   0.734711  0.066514                 0.053848        0.310522   0.234905
# 8   0.329324  0.100293                 0.064657        0.470500   0.305511
# 9   0.876295  0.193207                 0.045508        0.387505   0.131129
# 10  0.377879  0.010385                 0.009768        0.826427   0.054093
# 11  0.972964  0.074517                 0.028744        0.083283   0.156215
# 12  0.936502  0.549723                 0.385005        0.470905   0.450440
# 13  0.011996  0.057747                 0.132274        0.883086   0.014023
# 14  0.087965  0.044955                 0.013087        0.236448   0.160850
# 15  0.486758  0.285570                 0.079231        0.591259   0.212674
# 16  0.312362  0.436179                 0.052265        0.339755   0.107749
# 17  0.326311  0.139757                 0.223687        0.590160   0.285738
# 18  0.072127  0.025910                 0.055157        0.144416   0.075298
# 19  0.924495  0.027221                 0.005659        0.426798   0.119592
# 20  0.116482  0.127119                 0.026263        0.556502   0.992924
# 21  0.769924  0.584580                 0.048808        0.613156   0.208874
# 22  0.101979  0.038263                 0.097063        0.355754   0.392662
# 23  0.103798  0.023130                 0.048047        0.376484   0.146339
# 24  0.962993  0.248705                 0.080922        0.207497   0.235999
# 25  0.878054  0.182176                 0.045917        0.125505   0.162288
#
#     data_lakehouse  data_mesh  data_orchestration  data_transform  \
# 0         0.285507   0.515945            0.544580        0.237736
# 1         0.144968   0.177162            0.788386        0.647944
# 2         0.173472   0.254806            0.519185        0.496813
# 3         0.021803   0.092731            0.347691        0.077574
# 4         0.202316   0.030059            0.089702        0.056414
# 5         0.253639   0.154191            0.625179        0.124693
# 6         0.238004   0.180866            0.062305        0.143855
# 7         0.205466   0.235982            0.251255        0.299283
# 8         0.292468   0.277067            0.412039        0.310724
# 9         0.229841   0.222526            0.290090        0.372212
# 10        0.302744   0.084788            0.534160        0.593011
# 11        0.235905   0.322280            0.333848        0.344901
# 12        0.593217   0.582859            0.522485        0.466874
# 13        0.002504   0.265605            0.840699        0.199658
# 14        0.179282   0.728856            0.336160        0.269643
# 15        0.366457   0.582996            0.376614        0.413401
# 16        0.036662   0.125807            0.727814        0.211523
# 17        0.238195   0.315908            0.591882        0.435180
# 18        0.000643   0.110129            0.437134        0.139495
# 19        0.019204   0.352854            0.516862        0.154322
# 20        0.095303   0.249413            0.915069        0.215883
# 21        0.384115   0.192265            0.249599        0.306279
# 22        0.403455   0.483176            0.419670        0.420478
# 23        0.375640   0.226111            0.347103        0.298390
# 24        0.315218   0.311319            0.235030        0.320939
# 25        0.145944   0.148986            0.100657        0.191071
#
#     data_warehouse  etl_jobs  learning  scheduling  streaming
# 0         0.219351  0.069878  0.328071    0.040957   0.066578
# 1         0.700686  0.048917  0.979040    0.158083   0.155553
# 2         0.445353  0.219436  0.808945    0.584255   0.510787
# 3         0.015754  0.017437  0.938391    0.089701   0.077023
# 4         0.016460  0.027749  0.911352    0.103728   0.388229
# 5         0.098559  0.048577  0.399778    0.197562   0.741686
# 6         0.054419  0.034067  0.901122    0.047473   0.168244
# 7         0.197366  0.076045  0.799596    0.256644   0.294716
# 8         0.266008  0.130638  0.868781    0.226601   0.307237
# 9         0.268899  0.185267  0.985058    0.194271   0.678592
# 10        0.200702  0.019013  0.995111    0.217209   0.255360
# 11        0.052662  0.104783  0.549151    0.164211   0.184058
# 12        0.349736  0.447746  0.893935    0.704987   0.548976
# 13        0.230440  0.002920  0.936461    0.003749   0.059484
# 14        0.178058  0.058357  0.594096    0.223628   0.133011
# 15        0.142787  0.124288  0.593211    0.191470   0.222216
# 16        0.177575  0.160671  0.509085    0.366641   0.130626
# 17        0.490567  0.253085  0.624989    0.469784   0.296500
# 18        0.262649  0.063167  0.709675    0.119675   0.161349
# 19        0.161543  0.131277  0.847116    0.466948   0.096370
# 20        0.706747  0.033931  0.830419    0.223910   0.141736
# 21        0.228156  0.286485  0.948125    0.061397   0.289237
# 22        0.193360  0.183737  0.992942    0.344434   0.460542
# 23        0.116606  0.062952  0.998190    0.179613   0.245240
# 24        0.201492  0.112973  0.935020    0.247678   0.340567
# 25        0.106329  0.078658  0.301566    0.086557   0.295934
